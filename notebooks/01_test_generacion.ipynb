# %%
import sys
from pathlib import Path

# El notebook vive en notebooks/, pero nuestro loader.py está en src/rag/
# Añadimos "src" al path de Python para poder importarlo como si fuera una librería más
sys.path.append(str(Path.cwd().parent / "src"))

from rag.loader import cargar_documento
